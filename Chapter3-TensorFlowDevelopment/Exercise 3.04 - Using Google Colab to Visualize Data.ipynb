# %%
import tensorflow as tf
print('TF version:', tf.__version__)
# Out:
# TF version: 2.8.2

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
df = pd.read_csv("/content/gdrive/MyDrive/Datasets/Summary of Weather.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (7,8,18,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#      STA      Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 0  10001  1942-7-1  1.016          NaN  25.555556  22.222222  23.888889
# 1  10001  1942-7-2      0          NaN  28.888889  21.666667  25.555556
# 2  10001  1942-7-3   2.54          NaN  26.111111  22.222222  24.444444
# 3  10001  1942-7-4   2.54          NaN  26.666667  22.222222  24.444444
# 4  10001  1942-7-5      0          NaN  26.666667  21.666667  24.444444
#
#   Snowfall PoorWeather  YR  ...  FB  FTI ITH  PGT  TSHDSBRSGF  SD3  RHX  RHN  \
# 0      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 1      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 2      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 3      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 4      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
#
#   RVG  WTE
# 0 NaN  NaN
# 1 NaN  NaN
# 2 NaN  NaN
# 3 NaN  NaN
# ...

# %%
df.drop("Date", axis=1, inplace=True)

# %%
df1 = df.iloc[:,2:6].dropna()

# %%
df1.head()
# Out:
#        WindGustSpd    MaxTemp    MinTemp   MeanTemp
# 51177       29.632  27.222222  22.222222  25.000000
# 51178       59.264  27.777778  22.777778  25.555556
# 51179       50.004  27.777778  22.777778  25.555556
# 51180       40.744  26.666667  23.888889  25.555556
# 51181       51.856  26.111111  23.888889  25.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 532 entries, 51177 to 64046
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   WindGustSpd  532 non-null    float64
#  1   MaxTemp      532 non-null    float64
#  2   MinTemp      532 non-null    float64
#  3   MeanTemp     532 non-null    float64
# dtypes: float64(4)
# memory usage: 20.8 KB

# %%
import numpy as np
df1 = np.asarray(df1).astype(np.float32)
random_tensor = tf.random.normal((df1.shape[1],1))

# %%
tf.matmul(df1, random_tensor)
# Out:
# <tf.Tensor: shape=(532, 1), dtype=float32, numpy=
# array([[ 7.62738347e-01],
#        [-8.71616554e+00],
#        [-5.71149063e+00],
#        [-4.62486935e+00],
#        [-8.78542805e+00],
#        [-6.53445768e+00],
#        [-4.73165274e+00],
#        [-7.97917128e+00],
#        [-7.60026789e+00],
#        [-7.19618750e+00],
#        [-5.37256956e+00],
#        [-1.18360901e+01],
#        [-1.32348166e+01],
#        [-6.73131180e+00],
#        [-1.10990973e+01],
#        [-7.90390444e+00],
#        [-9.07425880e+00],
#        [-1.08770638e+01],
#        [-1.00648012e+01],
#        [-9.62920475e+00],
#        [-3.83341837e+00],
#        [-5.43936968e+00],
#        [-9.18104267e+00],
#        [-1.42967737e+00],
#        [-8.48402786e+00],
#        [-6.71869218e-01],
#        [-1.51565170e+00],
#        [-9.22102451e+00],
#        [-8.11523056e+00],
#        [-8.01915455e+00],
#        [-1.24285612e+01],
#        [-1.38064756e+01],
#        [-8.82294750e+00],
# ...
