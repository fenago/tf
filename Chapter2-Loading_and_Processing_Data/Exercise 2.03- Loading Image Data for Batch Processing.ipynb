# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# import requests
# from io import BytesIO
# from PIL import Image
url = 'https://github.com/fenago/tf/tree/main/Chapter2-Loading_and_Processing_Data/dataset/image_data'

# %%
training_set = train_datagen.flow_from_directory('dataset/',\
                    target_size = (64, 64),\
                    batch_size = 25,\
                    class_mode = 'binary')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-75c19853e747> in <module>
# ----> 1 training_set = train_datagen.flow_from_directory(url,\
#       2                     target_size = (64, 64),\
#       3                     batch_size = 25,\
#       4                     class_mode = 'binary')
#
# ~\anaconda3\envs\tf_ws\lib\site-packages\keras\preprocessing\image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     974             and `y` is a numpy array of corresponding labels.
#     975     """
# --> 976     return DirectoryIterator(
#     977         directory,
#     978         self,
#
# ...

# %%
import matplotlib.pyplot as plt
def show_batch(image_batch, label_batch):
    lookup = {v: k for k, v in training_set.class_indices.items()}
    label_batch = [lookup[label] for label in label_batch]
    plt.figure(figsize=(10,10))
    for n in range(15):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        plt.title(label_batch[n].title())
        plt.axis('off')

# %%
image_batch, label_batch = next(training_set)
show_batch(image_batch, label_batch)
